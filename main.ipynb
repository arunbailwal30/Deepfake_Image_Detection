# %%
# TensorFlow and tf.keras
import tensorflow as tf
import tensorflow.keras.layers 
# Helper libraries
import numpy as np
import matplotlib.pyplot as plt
import pathlib

print(tf.__version__)
# Out:
# 2026-03-19 14:18:36.943463: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2.20.0

# %%
LEARNING_RATE = 0.0001
EPOCHS = 100

path = "/home/arun/.cache/kagglehub/datasets/manjilkarki/deepfake-and-real-images/versions/1/Dataset"


batch_size = 32
img_height = 180
img_width = 180

train_ds = tf.keras.utils.image_dataset_from_directory(
    path+"/Train",
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    path+"/Train",
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size
)

class_names = train_ds.class_names
# Out:
# Found 140002 files belonging to 2 classes.
# Using 112002 files for training.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1773910152.766383    5416 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1763 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Found 140002 files belonging to 2 classes.
# Using 28000 files for validation.

# %%
num_classes = len(class_names)

model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(256, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(64, activation='relu'),
  tf.keras.layers.Dense(32, activation='relu'),
  tf.keras.layers.Dense(num_classes)
])

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=10
)
# Out:
# Epoch 1/10
# 2026-03-19 14:19:59.496843: I external/local_xla/xla/service/service.cc:163] XLA service 0x79db2015e430 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-03-19 14:19:59.496932: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2026-03-19 14:19:59.576443: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-03-19 14:20:00.183377: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91701
# 2026-03-19 14:20:00.411123: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-19 14:20:00.411649: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-19 14:20:00.411734: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-19 14:20:00.411787: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2026-03-19 14:20:02.353546: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_823', 100 bytes spill stores, 100 bytes spill loads
#
# 2026-03-19 14:20:03.788105: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1224', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-03-19 14:20:04.551863: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1224', 8 bytes spill stores, 8 bytes spill loads
#
# 2026-03-19 14:20:04.714874: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1206', 520 bytes spill stores, 520 bytes spill loads
#
# 2026-03-19 14:20:06.514736: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1224', 468 bytes spill stores, 468 bytes spill loads
#
# 2026-03-19 14:20:06.551720: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1222', 520 bytes spill stores, 520 bytes spill loads
#
# I0000 00:00:1773910217.267378    5628 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 3501/3501 ━━━━━━━━━━━━━━━━━━━━ 202s 52ms/step - accuracy: 0.8510 - loss: 0.3248 - val_accuracy: 0.9160 - val_loss: 0.2023
# Epoch 2/10
# 3501/3501 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9212 - loss: 0.1906
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.fit(
#       2   train_ds,
#       3   validation_data=val_ds,
#       4   epochs=10
#       5 )
#
# File ~/project/env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/project/env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:423, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     412 if getattr(self, "_eval_epoch_iterator", None) is None:
#     413     self._eval_epoch_iterator = TFEpochIterator(
#     414         x=val_x,
#     415         y=val_y,
#    (...)
#     421         shuffle=False,
#     422     )
# --> 423 val_logs = self.evaluate(
#     424     x=val_x,
#     425     y=val_y,
#     426     sample_weight=val_sample_weight,
#     427     batch_size=validation_batch_size or batch_size,
#     428     steps=validation_steps,
#     429     callbacks=callbacks,
#     430     return_dict=True,
#     431     _use_cached_eval_dataset=True,
#     432 )
#     433 val_logs = {
#     434     f"val_{name}": val for name, val in val_logs.items()
#     435 }
#     436 epoch_logs.update(val_logs)
#
# File ~/project/env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/project/env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:511, in TensorFlowTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     509 for begin_step, end_step, iterator in epoch_iterator:
#     510     callbacks.on_test_batch_begin(begin_step)
# --> 511     logs = self.test_function(iterator)
#     512     callbacks.on_test_batch_end(end_step, logs)
#     513     if self.stop_evaluating:
#
# File ~/project/env/lib/python3.10/site-packages/keras/src/backend/tensorflow/trainer.py:241, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     237 def function(iterator):
#     238     if isinstance(
#     239         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     240     ):
# --> 241         opt_outputs = multi_step_on_iterator(iterator)
#     242         if not opt_outputs.has_value():
#     243             raise StopIteration
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/util/traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py:878, in Function._call(self, *args, **kwds)
#     875 self._lock.release()
#     876 # In this case we have not created variables on the first call. So we can
#     877 # run the first trace but we should fail if variables are created.
# --> 878 results = tracing_compilation.call_function(
#     879     args, kwds, self._variable_creation_config
#     880 )
#     881 if self._created_variables:
#     882   raise ValueError("Creating variables on a non-first call to a function"
#     883                    " decorated with tf.function.")
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/eager/polymorphic_function/atomic_function.py:217, in AtomicFunction.call_preflattened(self, args)
#     215 """Calls with flattened tensor inputs and returns the structured output."""
#     216 flat_outputs = self.call_flat(*args)
# --> 217 return self.function_type.pack_output(flat_outputs)
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/core/function/polymorphism/function_type.py:450, in FunctionType.pack_output(self, flat_values)
#     448   raise ValueError("Can not pack outputs for undefined output type.")
#     449 else:
# --> 450   return self.output.from_tensors(iter(flat_values))
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/framework/type_spec.py:260, in TypeSpec.from_tensors(self, tensors)
#     257 @doc_controls.do_not_doc_inheritable
#     258 def from_tensors(self, tensors):
#     259   """See TraceType base class for details. Do not override."""
# --> 260   components = nest.map_structure(
#     261       lambda spec: spec.from_tensors(tensors),
#     262       self._component_specs
#     263   )
#     264   return self._from_components(components)
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/util/nest.py:628, in map_structure(func, *structure, **kwargs)
#     542 @tf_export("nest.map_structure")
#     543 def map_structure(func, *structure, **kwargs):
#     544   """Creates a new structure by applying `func` to each atom in `structure`.
#     545
#     546   Refer to [tf.nest](https://www.tensorflow.org/api_docs/python/tf/nest)
#    (...)
#     626     ValueError: If wrong keyword arguments are provided.
#     627   """
# --> 628   return nest_util.map_structure(
#     629       nest_util.Modality.CORE, func, *structure, **kwargs
#     630   )
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/util/nest_util.py:1065, in map_structure(modality, func, *structure, **kwargs)
#     968 """Creates a new structure by applying `func` to each atom in `structure`.
#     969
#     970 - For Modality.CORE: Refer to
#    (...)
#    1062   ValueError: If wrong keyword arguments are provided.
#    1063 """
#    1064 if modality == Modality.CORE:
# -> 1065   return _tf_core_map_structure(func, *structure, **kwargs)
#    1066 elif modality == Modality.DATA:
#    1067   return _tf_data_map_structure(func, *structure, **kwargs)
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/util/nest_util.py:1103, in _tf_core_map_structure(func, *structure, **kwargs)
#    1100 flat_structure = (_tf_core_flatten(s, expand_composites) for s in structure)
#    1101 entries = zip(*flat_structure)
# -> 1103 return _tf_core_pack_sequence_as(
#    1104     structure[0],
#    1105     [func(*x) for x in entries],
#    1106     expand_composites=expand_composites,
#    1107 )
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/util/nest_util.py:919, in _tf_core_pack_sequence_as(structure, flat_sequence, expand_composites, sequence_fn)
#     912   if len(flat_structure) != len(flat_sequence):
#     913     # pylint: disable=raise-missing-from
#     914     raise ValueError(
#     915         "Could not pack sequence. Structure had %d atoms, but "
#     916         "flat_sequence had %d items.  Structure: %s, flat_sequence: %s."
#     917         % (len(flat_structure), len(flat_sequence), structure, flat_sequence)
#     918     )
# --> 919 return sequence_fn(structure, packed)
#
# File ~/project/env/lib/python3.10/site-packages/tensorflow/python/util/nest_util.py:244, in sequence_like(instance, args)
#     240 elif isinstance(instance, _wrapt.ObjectProxy):
#     241   # For object proxies, first create the underlying type and then re-wrap it
#     242   # in the proxy type.
#     243   return type(instance)(sequence_like(instance.__wrapped__, args))
# --> 244 elif isinstance(instance, CustomNestProtocol):
#     245   metadata = instance.__tf_flatten__()[0]
#     246   return instance.__tf_unflatten__(metadata, tuple(args))
#
# File /usr/lib/python3.10/typing.py:1502, in _ProtocolMeta.__instancecheck__(cls, instance)
#    1493 if (
#    1494     getattr(cls, '_is_protocol', False) and
#    1495     not getattr(cls, '_is_runtime_protocol', False) and
#    1496     not _allow_reckless_class_checks(depth=2)
#    1497 ):
#    1498     raise TypeError("Instance and class checks can only be used with"
#    1499                     " @runtime_checkable protocols")
#    1501 if ((not getattr(cls, '_is_protocol', False) or
# -> 1502         _is_callable_members_only(cls)) and
#    1503         issubclass(instance.__class__, cls)):
#    1504     return True
#    1505 if cls._is_protocol:
#
# File /usr/lib/python3.10/typing.py:1427, in _is_callable_members_only(cls)
#    1425 def _is_callable_members_only(cls):
#    1426     # PEP 544 prohibits using issubclass() with protocols that have non-method members.
# -> 1427     return all(callable(getattr(cls, attr, None)) for attr in _get_protocol_attrs(cls))
#
# File /usr/lib/python3.10/typing.py:1419, in _get_protocol_attrs(cls)
#    1417     continue
#    1418 annotations = getattr(base, '__annotations__', {})
# -> 1419 for attr in list(base.__dict__.keys()) + list(annotations.keys()):
#    1420     if not attr.startswith('_abc_') and attr not in EXCLUDED_ATTRIBUTES:
#    1421         attrs.add(attr)
#
# KeyboardInterrupt:
